# %% [markdown]
# # Example communes

# %%
import pandas as pd

comm = pd.read_csv("donnees_communes.csv", sep=";")
comm_min = comm[["REG", "DEP", "Région", "COM"]]
comm
# Out:
#        REG                Région  DEP  CODARR CODCAN  CODCOM    COM  \
# 0       84  Auvergne-Rhône-Alpes   01       2     08       1  01001
# 1       84  Auvergne-Rhône-Alpes   01       1     01       2  01002
# 2       84  Auvergne-Rhône-Alpes   01       1     01       4  01004
# 3       84  Auvergne-Rhône-Alpes   01       2     22       5  01005
# 4       84  Auvergne-Rhône-Alpes   01       1     04       6  01006
# ...    ...                   ...  ...     ...    ...     ...    ...
# 34965    4            La Réunion  974       1     04     420  97420
# 34966    4            La Réunion  974       3     06     421  97421
# 34967    4            La Réunion  974       2     99     422  97422
# 34968    4            La Réunion  974       4     14     423  97423
# 34969    4            La Réunion  974       2     16     424  97424
#
#                        Commune   PMUN  PCAP   PTOT
# 0      L'Abergement-Clémenciat    832    16    848
# 1        L'Abergement-de-Varey    267     6    273
# 2            Ambérieu-en-Bugey  14854   386  15240
# 3          Ambérieux-en-Dombes   1897    24   1921
# 4                      Ambléon    113     0    113
# ...                        ...    ...   ...    ...
# 34965           Sainte-Suzanne  24293   245  24538
# 34966                  Salazie   7243    76   7319
# 34967                Le Tampon  81943   925  82868
# 34968        Les Trois-Bassins   6899    90   6989
# 34969                   Cilaos   5390    47   5437
#
# [34970 rows x 11 columns]

# %%
analys = comm.npd.analysis()
print(analys.tree())
# Out:
# -1: root-derived (34970)
#    2 : DEP (34870 - 100)
#       0 : REG (83 - 17)
#          1 : Région (0 - 17)
#    3 : CODARR (34961 - 9)
#    4 : CODCAN (34911 - 59)
#    5 : CODCOM (34062 - 908)
#    6 : COM (0 - 34970)
#    7 : Commune (2250 - 32720)
#    8 : PMUN (29075 - 5895)
#    9 : PCAP (34262 - 708)
#    10: PTOT (28996 - 5974)

# %%
import json
from tab_dataset.dataset import Sdataset

comm_sd = Sdataset(comm_min)
jsn = comm_sd.to_ntv(modecodec="optimize").to_obj(encoded=False)
len(json.dumps(jsn))
# jsn
# Out:
# 452227

# %%
import cbor2

len(cbor2.dumps(jsn))
# Out:
# 271414

# %%
len(comm_min.to_parquet())
# Out:
# 218847

# %%
comm = pd.read_csv("v_commune_2024.csv", sep=",")
comm
# Out:
#       TYPECOM    COM   REG  DEP  CTCD  ARR  TNCC                    NCC  \
# 0         COM  01001  84.0   01   01D  012     5  ABERGEMENT CLEMENCIAT
# 1         COM  01002  84.0   01   01D  011     5    ABERGEMENT DE VAREY
# 2         COM  01004  84.0   01   01D  011     1      AMBERIEU EN BUGEY
# 3         COM  01005  84.0   01   01D  012     1    AMBERIEUX EN DOMBES
# 4         COM  01006  84.0   01   01D  011     1                AMBLEON
# ...       ...    ...   ...  ...   ...  ...   ...                    ...
# 37539     COM  97613   6.0  976  976D  NaN     0          M TSANGAMOUJI
# 37540     COM  97614   6.0  976  976D  NaN     1               OUANGANI
# 37541     COM  97615   6.0  976  976D  NaN     0               PAMANDZI
# 37542     COM  97616   6.0  976  976D  NaN     0                   SADA
# 37543     COM  97617   6.0  976  976D  NaN     0               TSINGONI
#
#                       NCCENR                  LIBELLE    CAN  COMPARENT
# 0      Abergement-Clémenciat  L'Abergement-Clémenciat   0108        NaN
# 1        Abergement-de-Varey    L'Abergement-de-Varey   0101        NaN
# 2          Ambérieu-en-Bugey        Ambérieu-en-Bugey   0101        NaN
# 3        Ambérieux-en-Dombes      Ambérieux-en-Dombes   0122        NaN
# 4                    Ambléon                  Ambléon   0104        NaN
# ...                      ...                      ...    ...        ...
# 37539          M'Tsangamouji            M'Tsangamouji  97613        NaN
# 37540               Ouangani                 Ouangani  97610        NaN
# 37541               Pamandzi                 Pamandzi  97611        NaN
# 37542                   Sada                     Sada  97612        NaN
# 37543               Tsingoni                 Tsingoni  97613        NaN
#
# [37544 rows x 12 columns]
